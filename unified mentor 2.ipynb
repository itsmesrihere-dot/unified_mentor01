# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-8c778906-497a-4928-8634-06fa140a7cbe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c778906-497a-4928-8634-06fa140a7cbe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('Atlantic_Spain.csv')
df.head()
# Out:
#          date  position         song                      artist  popularity  \
# 0  18-05-2024         1    Supernova                       Saiko          84
# 1  18-05-2024         2     EL TONTO                 Lola Indigo          83
# 2  18-05-2024         3    Acróstico                     Shakira          81
# 3  18-05-2024         4         BESO    ROSALÍA & Rauw Alejandro          96
# 4  18-05-2024         5  El Merengue  Marshmello & Manuel Turizo          91
#
#    duration_ms album_type  total_tracks  is_explicit  \
# 0       190909     single             1        False
# 1       187986      album            11        False
# 2       170785     single             1        False
# 3       194543     single             3        False
# 4       189668     single             1        False
#
#                                      album_cover_url
# 0  https://i.scdn.co/image/ab67616d0000b273c3f5b9...
# 1  https://i.scdn.co/image/ab67616d0000b273daab36...
# ...

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27800 entries, 0 to 27799
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             27800 non-null  object
#  1   position         27800 non-null  int64
#  2   song             27800 non-null  object
#  3   artist           27800 non-null  object
#  4   popularity       27800 non-null  int64
#  5   duration_ms      27800 non-null  int64
#  6   album_type       27800 non-null  object
#  7   total_tracks     27800 non-null  int64
#  8   is_explicit      27800 non-null  bool
#  9   album_cover_url  27800 non-null  object
# dtypes: bool(1), int64(4), object(5)
# memory usage: 1.9+ MB
# date               0
# position           0
# song               0
# artist             0
# popularity         0
# duration_ms        0
# album_type         0
# total_tracks       0
# is_explicit        0
# album_cover_url    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
import matplotlib.pyplot as plt

# %%
df.hist(figsize=(10,8))
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#               position  popularity  duration_ms  total_tracks  is_explicit
# position      1.000000   -0.200252    -0.008963      0.074475    -0.044517
# popularity   -0.200252    1.000000     0.033198     -0.053562     0.111389
# duration_ms  -0.008963    0.033198     1.000000     -0.101378     0.189163
# total_tracks  0.074475   -0.053562    -0.101378      1.000000     0.271548
# is_explicit  -0.044517    0.111389     0.189163      0.271548     1.000000

# %%
import seaborn as sns
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.show()

# %%
df.plot()
plt.show()

# %%
df.shape
# Out:
# (27800, 10)

# %% [markdown]
# *  the dataset contains 27800 records and 10 columns
# *  missing values were handled using data cleaning   techniques
# *  correlation analysis shows relationship between variables
# *  data visualization helped identity patterns and trends

# %% [markdown]
# ## Conclusion
#
# This project analyzed the dataset using Python libraries like Pandas, Matplotlib, and Seaborn. Data cleaning was performed to handle missing values, and visualization techniques were used to understand patterns and relationships between variables. The analysis provided meaningful insights and helped in better understanding of the dataset.
